# %%
import pandas as pd

# %%
df=pd.read_csv('blinkit_customers.csv')

# %%
df.head(10)
# Out:
#    customer_id      customer_name                      email         phone  \
# 0     97475543      Niharika Nagi     ektataneja@example.org  912987579691
# 1     22077605       Megha Sachar       vedant45@example.com  915123179717
# 2     47822591         Hema Bahri      samiazaan@example.com  910034076149
# 3     79726146         Zaitra Vig      ishanvi87@example.org  916264232390
# 4     57102800       Januja Verma   atideshpande@example.org  917293526596
# 5     54748429         Darsh More         ynayar@example.org  912582120513
# 6     49152878     Patrick Sandhu  zehaanmahajan@example.org  912413014420
# 7     16379942  Harshil Kuruvilla  pathakanirudh@example.org  913807361990
# 8     11071601         Ojas Ahuja        sneha11@example.com  912865080618
# 9     68164013      Netra Chander       hwarrior@example.org  917645901970
#
#                                address           area  pincode  \
# 0  23, Nayar Path, Bihar Sharif-154625          Udupi   321865
# ...

# %%
df.describe(include='all')
# Out:
#          customer_id customer_name               email         phone  \
# count   2.500000e+03          2500                2500  2.500000e+03
# unique           NaN          2491                2496           NaN
# top              NaN  Aarush Ratti  ydevan@example.net           NaN
# freq             NaN             2                   2           NaN
# mean    4.989961e+07           NaN                 NaN  9.150532e+11
# std     2.919266e+07           NaN                 NaN  2.882835e+09
# min     3.181300e+04           NaN                 NaN  9.100132e+11
# 25%     2.402443e+07           NaN                 NaN  9.125946e+11
# 50%     5.000044e+07           NaN                 NaN  9.150236e+11
# 75%     7.595459e+07           NaN                 NaN  9.176256e+11
# max     9.989390e+07           NaN                 NaN  9.199988e+11
#
#                                   address   area        pincode  \
# count                                2500   2500    2500.000000
# ...

# %%
df.dtypes
# Out:
# customer_id            int64
# customer_name         object
# email                 object
# phone                  int64
# address               object
# area                  object
# pincode                int64
# registration_date     object
# customer_segment      object
# total_orders           int64
# avg_order_value      float64
# dtype: object

# %%
df['registration_date']=pd.to_datetime(df['registration_date'])

# %%
df.isnull().sum()
# Out:
# customer_id          0
# customer_name        0
# email                0
# phone                0
# address              0
# area                 0
# pincode              0
# registration_date    0
# customer_segment     0
# total_orders         0
# avg_order_value      0
# dtype: int64

# %%
print(df.duplicated().sum())
print(df['customer_id'].duplicated().sum())
# Out:
# 0
# 0

# %%
df.shape
# Out:
# (2500, 11)

# %%
df1=pd.read_csv('blinkit_customer_feedback.csv')
df2=pd.read_csv('blinkit_delivery_performance.csv')

# %%
df1.head(10)
# Out:
#    feedback_id    order_id  customer_id  rating  \
# 0      2234710  1961864118     30065862       4
# 1      5450964  1549769649      9573071       3
# 2       482108  9185164487     45477575       3
# 3      4823104  9644738826     88067569       4
# 4      3537464  5427684290     83298567       3
# 5      4089724  3265154092     43367112       2
# 6       230696  4898355547     13284996       4
# 7      2259308  6568151549     88866835       2
# 8      7380970  6006693867     24496983       3
# 9      2257242   374186990     52215833       3
#
#                           feedback_text feedback_category sentiment  \
# 0         It was okay, nothing special.          Delivery   Neutral
# 1              The order was incorrect.    App Experience  Negative
# 2         It was okay, nothing special.    App Experience   Neutral
# 3      The product met my expectations.    App Experience   Neutral
# 4  Product was damaged during delivery.          Delivery  Negative
# ...

# %%
df1.describe(include='all')
# Out:
#          feedback_id      order_id   customer_id      rating  \
# count   5.000000e+03  5.000000e+03  5.000000e+03  5000.00000
# unique           NaN           NaN           NaN         NaN
# top              NaN           NaN           NaN         NaN
# freq             NaN           NaN           NaN         NaN
# mean    5.013616e+06  5.029129e+09  5.009685e+07     3.34440
# std     2.857341e+06  2.863533e+09  2.919082e+07     1.18982
# min     9.470000e+02  6.046500e+04  3.181300e+04     1.00000
# 25%     2.576690e+06  2.531421e+09  2.404314e+07     3.00000
# 50%     5.005833e+06  5.074378e+09  4.997808e+07     4.00000
# 75%     7.486478e+06  7.488579e+09  7.621215e+07     4.00000
# max     9.999293e+06  9.998298e+09  9.989390e+07     5.00000
#
#                            feedback_text feedback_category sentiment  \
# count                               5000              5000      5000
# unique                                25                 4         3
# ...

# %%
df1.dtypes
# Out:
# feedback_id           int64
# order_id              int64
# customer_id           int64
# rating                int64
# feedback_text        object
# feedback_category    object
# sentiment            object
# feedback_date        object
# dtype: object

# %%
df1['feedback_date']=pd.to_datetime(df1['feedback_date'])

# %%
df1.isnull().sum()
# Out:
# feedback_id          0
# order_id             0
# customer_id          0
# rating               0
# feedback_text        0
# feedback_category    0
# sentiment            0
# feedback_date        0
# dtype: int64

# %%
print(df1.duplicated().sum())
print(df1['customer_id'].duplicated().sum())
print(df1['feedback_id'].duplicated().sum())
print(df1['order_id'].duplicated().sum())
# Out:
# 0
# 2828
# 0
# 0

# %%
df1.shape
# Out:
# (5000, 8)

# %%
df2.head(10)
# Out:
#      order_id  delivery_partner_id        promised_time          actual_time  \
# 0  1961864118                63230  2024-07-17 08:52:01  2024-07-17 08:47:01
# 1  1549769649                14983  2024-05-28 13:25:29  2024-05-28 13:27:29
# 2  9185164487                39859  2024-09-23 13:25:12  2024-09-23 13:29:12
# 3  9644738826                61497  2023-11-24 16:34:56  2023-11-24 16:33:56
# 4  5427684290                84315  2023-11-20 05:17:39  2023-11-20 05:18:39
# 5  3265154092                  554  2023-03-18 16:49:51  2023-03-18 16:48:51
# 6  4898355547                14630  2023-04-16 19:01:37  2023-04-16 19:02:37
# 7  6568151549                67714  2024-03-31 06:37:48  2024-03-31 06:39:48
# 8  6006693867                91362  2023-07-14 00:02:36  2023-07-14 00:05:36
# 9   374186990                77203  2023-08-09 01:37:30  2023-08-09 01:44:30
#
#    delivery_time_minutes  distance_km   delivery_status reasons_if_delayed
# ...

# %%
df2.describe(include='all')
# Out:
#             order_id  delivery_partner_id        promised_time  \
# count   5.000000e+03          5000.000000                 5000
# unique           NaN                  NaN                 4999
# top              NaN                  NaN  2024-10-13 14:06:50
# freq             NaN                  NaN                    2
# mean    5.029129e+09         50050.318200                  NaN
# std     2.863533e+09         28802.276922                  NaN
# min     6.046500e+04            43.000000                  NaN
# 25%     2.531421e+09         24928.500000                  NaN
# 50%     5.074378e+09         50262.500000                  NaN
# 75%     7.488579e+09         74478.250000                  NaN
# max     9.998298e+09         99968.000000                  NaN
#
#                 actual_time  delivery_time_minutes  distance_km  \
# count                  5000            5000.000000  5000.000000
# unique                 5000                    NaN          NaN
# ...

# %%
df2.dtypes
# Out:
# order_id                   int64
# delivery_partner_id        int64
# promised_time             object
# actual_time               object
# delivery_time_minutes    float64
# distance_km              float64
# delivery_status           object
# reasons_if_delayed        object
# dtype: object

# %%
df2['promised_time']=pd.to_datetime(df2['promised_time'])
df2['actual_time']=pd.to_datetime(df2['actual_time'])

# %%
df2.isnull().sum()
# Out:
# order_id                    0
# delivery_partner_id         0
# promised_time               0
# actual_time                 0
# delivery_time_minutes       0
# distance_km                 0
# delivery_status             0
# reasons_if_delayed       1902
# dtype: int64

# %%
print(df2.duplicated().sum())
print(df2['order_id'].duplicated().sum())
print(df2['delivery_partner_id'].duplicated().sum())
# Out:
# 0
# 0
# 0

# %%
df2.shape
# Out:
# (5000, 8)

# %%
common_customer_ids = df1[df1['customer_id'].isin(df['customer_id'])]['customer_id'].unique()
print(f"Number of common customer IDs between df and df1: {len(common_customer_ids)}")
# Out:
# Number of common customer IDs between df and df1: 2172

# %%
print(df['customer_id'].nunique())
print(df1['customer_id'].nunique())
print(len(common_customer_ids))
# Out:
# 2500
# 2172
# 2172

# %%
from numpy import isin
common_order_ids=df2[df2['order_id'].isin(df1['order_id'])]['order_id'].unique()
print(f'number of common order id between df2 and df3:{len(common_order_ids)}')
# Out:
# number of common order id between df2 and df3:5000

# %%
print(df1['order_id'].nunique())
print(df2['order_id'].nunique())
print(len(common_order_ids))
# Out:
# 5000
# 5000
# 5000

# %%
order=pd.read_csv('blinkit_orders.csv')

# %%
order.head(10)
# Out:
#      order_id  customer_id           order_date promised_delivery_time  \
# 0  1961864118     30065862  2024-07-17 08:34:01    2024-07-17 08:52:01
# 1  1549769649      9573071  2024-05-28 13:14:29    2024-05-28 13:25:29
# 2  9185164487     45477575  2024-09-23 13:07:12    2024-09-23 13:25:12
# 3  9644738826     88067569  2023-11-24 16:16:56    2023-11-24 16:34:56
# 4  5427684290     83298567  2023-11-20 05:00:39    2023-11-20 05:17:39
# 5  3265154092     43367112  2023-03-18 16:29:51    2023-03-18 16:49:51
# 6  4898355547     13284996  2023-04-16 18:50:37    2023-04-16 19:01:37
# 7  6568151549     88866835  2024-03-31 06:26:48    2024-03-31 06:37:48
# 8  6006693867     24496983  2023-07-13 23:49:36    2023-07-14 00:02:36
# 9   374186990     52215833  2023-08-09 01:17:30    2023-08-09 01:37:30
#
#   actual_delivery_time   delivery_status  order_total payment_method  \
# 0  2024-07-17 08:47:01           On Time      3197.07           Cash
# ...

# %%
order.describe(include='all')
# Out:
#             order_id   customer_id           order_date  \
# count   5.000000e+03  5.000000e+03                 5000
# unique           NaN           NaN                 5000
# top              NaN           NaN  2023-08-23 12:04:18
# freq             NaN           NaN                    1
# mean    5.029129e+09  5.009685e+07                  NaN
# std     2.863533e+09  2.919082e+07                  NaN
# min     6.046500e+04  3.181300e+04                  NaN
# 25%     2.531421e+09  2.404314e+07                  NaN
# 50%     5.074378e+09  4.997808e+07                  NaN
# 75%     7.488579e+09  7.621215e+07                  NaN
# max     9.998298e+09  9.989390e+07                  NaN
#
#        promised_delivery_time actual_delivery_time delivery_status  \
# count                    5000                 5000            5000
# unique                   4999                 5000               3
# top       2024-10-13 14:06:50  2023-08-23 12:21:18         On Time
# ...

# %%
order.dtypes
# Out:
# order_id                    int64
# customer_id                 int64
# order_date                 object
# promised_delivery_time     object
# actual_delivery_time       object
# delivery_status            object
# order_total               float64
# payment_method             object
# delivery_partner_id         int64
# store_id                    int64
# dtype: object

# %%
order['order_date']=pd.to_datetime(order['order_date'])
order['actual_delivery_time']=pd.to_datetime(order['actual_delivery_time'])
order['promised_delivery_time']=pd.to_datetime(order['promised_delivery_time'])

# %%
order.isnull().sum()
# Out:
# order_id                  0
# customer_id               0
# order_date                0
# promised_delivery_time    0
# actual_delivery_time      0
# delivery_status           0
# order_total               0
# payment_method            0
# delivery_partner_id       0
# store_id                  0
# dtype: int64

# %%
print(order.duplicated().sum())
print(order['order_id'].duplicated().sum())
print(order['customer_id'].duplicated().sum())
print(order['delivery_partner_id'].duplicated().sum())
# Out:
# 0
# 0
# 2828
# 0

# %%
order.shape
# Out:
# (5000, 10)

# %%
order_item=pd.read_csv('blinkit_order_items.csv')

# %%
order_item.head(10)
# Out:
#      order_id  product_id  quantity  unit_price
# 0  1961864118      642612         3      517.03
# 1  1549769649      378676         1      881.42
# 2  9185164487      741341         2      923.84
# 3  9644738826      561860         1      874.78
# 4  5427684290      602241         2      976.55
# 5  3265154092      681063         1      321.28
# 6  4898355547       56589         3      517.77
# 7  6568151549      500739         2      359.98
# 8  6006693867      490939         1       80.25
# 9   374186990      760828         2      563.45

# %%
order_item.describe(include='all')
# Out:
#            order_id     product_id     quantity   unit_price
# count  5.000000e+03    5000.000000  5000.000000  5000.000000
# mean   5.029129e+09  509974.939600     2.006800   493.157900
# std    2.863533e+09  293678.307475     0.820542   298.075647
# min    6.046500e+04    4452.000000     1.000000    12.320000
# 25%    2.531421e+09  257719.000000     1.000000   227.220000
# 50%    5.074378e+09  540618.000000     2.000000   448.160000
# 75%    7.488579e+09  747801.000000     3.000000   781.080000
# max    9.998298e+09  993331.000000     3.000000   995.980000

# %%
order_item.dtypes
# Out:
# order_id        int64
# product_id      int64
# quantity        int64
# unit_price    float64
# dtype: object

# %%
print(order_item.duplicated().sum())
print(order_item['order_id'].duplicated().sum())
print(order_item['product_id'].duplicated().sum())
# Out:
# 0
# 0
# 4732

# %%
order_item['revenue']=order_item['unit_price']*order_item['quantity']

# %%
order_item.head(10)
# Out:
#      order_id  product_id  quantity  unit_price  revenue
# 0  1961864118      642612         3      517.03  1551.09
# 1  1549769649      378676         1      881.42   881.42
# 2  9185164487      741341         2      923.84  1847.68
# 3  9644738826      561860         1      874.78   874.78
# 4  5427684290      602241         2      976.55  1953.10
# 5  3265154092      681063         1      321.28   321.28
# 6  4898355547       56589         3      517.77  1553.31
# 7  6568151549      500739         2      359.98   719.96
# 8  6006693867      490939         1       80.25    80.25
# 9   374186990      760828         2      563.45  1126.90

# %%
order_item.shape
# Out:
# (5000, 5)

# %%
market_perf=pd.read_csv('blinkit_marketing_performance.csv')

# %%
market_perf.head(10)
# Out:
#    campaign_id          campaign_name        date target_audience  \
# 0       548299      New User Discount  2024-11-05         Premium
# 1       390914        Weekend Special  2024-11-05        Inactive
# 2       834385         Festival Offer  2024-11-05        Inactive
# 3       241523             Flash Sale  2024-11-05        Inactive
# 4       595111       Membership Drive  2024-11-05       New Users
# 5       176344     Category Promotion  2024-11-05        Inactive
# 6       875646  App Push Notification  2024-11-05         Premium
# 7         5516         Email Campaign  2024-11-05         Premium
# 8       989534       Referral Program  2024-11-05       New Users
# 9       243346      New User Discount  2024-11-04        Inactive
#
#         channel  impressions  clicks  conversions    spend  revenue_generated  \
# 0           App         3130     163           78  1431.85            4777.75
# 1           App         3925     494           45  4506.34            6238.11
# ...

# %%
market_perf.describe(include='all')
# Out:
#           campaign_id      campaign_name        date target_audience channel  \
# count     5400.000000               5400        5400            5400    5400
# unique            NaN                  9         600               4       4
# top               NaN  New User Discount  2023-03-17       New Users     App
# freq              NaN                600           9            1356    1374
# mean    501315.219074                NaN         NaN             NaN     NaN
# std     287611.524258                NaN         NaN             NaN     NaN
# min        243.000000                NaN         NaN             NaN     NaN
# 25%     249200.000000                NaN         NaN             NaN     NaN
# 50%     505012.500000                NaN         NaN             NaN     NaN
# 75%     752219.250000                NaN         NaN             NaN     NaN
# max     999950.000000                NaN         NaN             NaN     NaN
#
# ...

# %%
market_perf.dtypes
# Out:
# campaign_id            int64
# campaign_name         object
# date                  object
# target_audience       object
# channel               object
# impressions            int64
# clicks                 int64
# conversions            int64
# spend                float64
# revenue_generated    float64
# roas                 float64
# dtype: object

# %%
market_perf['date']=pd.to_datetime(market_perf['date'])

# %%
market_perf.isnull().sum()
# Out:
# campaign_id          0
# campaign_name        0
# date                 0
# target_audience      0
# channel              0
# impressions          0
# clicks               0
# conversions          0
# spend                0
# revenue_generated    0
# roas                 0
# dtype: int64

# %%
print(market_perf.duplicated().sum())
print(market_perf['campaign_id'].duplicated().sum())
# Out:
# 0
# 0

# %%
market_perf.shape
# Out:
# (5400, 11)

# %%
inv=pd.read_csv('blinkit_inventory.csv')
inv.head(10)
# Out:
#    product_id        date  stock_received  damaged_stock
# 0      153019  17-03-2023               4              2
# 1      848226  17-03-2023               4              2
# 2      965755  17-03-2023               1              0
# 3       39154  17-03-2023               4              0
# 4       34186  17-03-2023               3              2
# 5      478531  17-03-2023               4              2
# 6      812607  17-03-2023               4              0
# 7      818990  17-03-2023               4              0
# 8       14145  17-03-2023               0              2
# 9      847349  17-03-2023               0              2

# %%
inv.describe(include='all')
# Out:
#            product_id        date  stock_received  damaged_stock
# count    75172.000000       75172    75172.000000   75172.000000
# unique            NaN         600             NaN            NaN
# top               NaN  04-06-2023             NaN            NaN
# freq              NaN         150             NaN            NaN
# mean    514290.353097         NaN        1.962513       1.067791
# std     291277.971875         NaN        1.639961       0.997706
# min       4452.000000         NaN        0.000000       0.000000
# 25%     272170.000000         NaN        0.000000       0.000000
# 50%     542300.000000         NaN        3.000000       2.000000
# 75%     753354.000000         NaN        3.000000       2.000000
# max     993331.000000         NaN        4.000000       2.000000

# %%
inv.dtypes
# Out:
# product_id         int64
# date              object
# stock_received     int64
# damaged_stock      int64
# dtype: object

# %%
inv['date']=pd.to_datetime(inv['date'],dayfirst=True)

# %%
inv.isnull().sum()
# Out:
# product_id        0
# date              0
# stock_received    0
# damaged_stock     0
# dtype: int64

# %%
print(inv.duplicated().sum())
print(inv['product_id'].duplicated().sum())
# Out:
# 0
# 74904

# %%
inv.shape
# Out:
# (75172, 4)

# %%
inv_new=pd.read_csv('blinkit_inventoryNew.csv')
inv_new.head(10)
# Out:
#    product_id    date  stock_received  damaged_stock
# 0      153019  Mar-23               4              1
# 1      848226  Mar-23               4              1
# 2      965755  Mar-23               1              0
# 3       39154  Mar-23               4              0
# 4       34186  Mar-23               3              1
# 5      478531  Mar-23               4              1
# 6      812607  Mar-23               4              0
# 7      818990  Mar-23               4              0
# 8      284460  Mar-23               4              0
# 9      654297  Mar-23               4              1

# %%
inv_new.describe(include='all')
# Out:
#            product_id    date  stock_received  damaged_stock
# count    18105.000000   18105    18105.000000   18105.000000
# unique            NaN      21             NaN            NaN
# top               NaN  Jul-23             NaN            NaN
# freq              NaN    1076             NaN            NaN
# mean    514273.410163     NaN        1.589561       0.061254
# std     290295.868498     NaN        0.797942       0.265387
# min       4452.000000     NaN        1.000000       0.000000
# 25%     274207.000000     NaN        1.000000       0.000000
# 50%     540618.000000     NaN        1.000000       0.000000
# 75%     753354.000000     NaN        2.000000       0.000000
# max     993331.000000     NaN        4.000000       7.000000

# %%
inv_new.dtypes
# Out:
# product_id         int64
# date              object
# stock_received     int64
# damaged_stock      int64
# dtype: object

# %%
order_item.groupby('product_id')['unit_price'].nunique().sort_values(ascending=False)
# Out:
# product_id
# 993331    1
# 4452      1
# 6405      1
# 9436      1
# 11422     1
#          ..
# 52729     1
# 51036     1
# 41853     1
# 39154     1
# 36412     1
# Name: unit_price, Length: 268, dtype: int64

# %%
product=pd.read_csv('blinkit_products.csv')
product.head(10)
# Out:
#    product_id product_name             category                    brand  \
# 0      153019       Onions  Fruits & Vegetables               Aurora LLC
# 1       11422     Potatoes  Fruits & Vegetables           Ramaswamy-Tata
# 2      669378     Potatoes  Fruits & Vegetables          Chadha and Sons
# 3      848226     Tomatoes  Fruits & Vegetables           Barad and Sons
# 4      890623       Onions  Fruits & Vegetables  Sangha, Nagar and Varty
# 5      965755      Bananas  Fruits & Vegetables   Doshi, Sarraf and Sama
# 6      222892     Tomatoes  Fruits & Vegetables       Ramakrishnan-Ghose
# 7      516376       Onions  Fruits & Vegetables             Agarwal-Dhar
# 8       39154      Mangoes  Fruits & Vegetables   Suresh, Bose and Bajwa
# 9       34186      Mangoes  Fruits & Vegetables               Mandal-Kar
#
#     price      mrp  margin_percentage  shelf_life_days  min_stock_level  \
# 0  947.95  1263.93               25.0                3               13
# ...

# %%
product.describe(include='all')
# Out:
#            product_id product_name           category      brand       price  \
# count      268.000000          268                268        268  268.000000
# unique            NaN           51                 11        267         NaN
# top               NaN   Pet Treats  Dairy & Breakfast  Jha Group         NaN
# freq              NaN           12                 30          2         NaN
# mean    514855.940299          NaN                NaN        NaN  488.356828
# std     291391.529820          NaN                NaN        NaN  298.487200
# min       4452.000000          NaN                NaN        NaN   12.320000
# 25%     273697.750000          NaN                NaN        NaN  226.717500
# 50%     541459.000000          NaN                NaN        NaN  442.185000
# 75%     754334.000000          NaN                NaN        NaN  779.445000
# max     993331.000000          NaN                NaN        NaN  995.980000
#
# ...

# %%
product.dtypes
# Out:
# product_id             int64
# product_name          object
# category              object
# brand                 object
# price                float64
# mrp                  float64
# margin_percentage    float64
# shelf_life_days        int64
# min_stock_level        int64
# max_stock_level        int64
# dtype: object

# %%
product.isnull().sum()
# Out:
# product_id           0
# product_name         0
# category             0
# brand                0
# price                0
# mrp                  0
# margin_percentage    0
# shelf_life_days      0
# min_stock_level      0
# max_stock_level      0
# dtype: int64

# %%
print(product.duplicated().sum())
print(product['product_id'].duplicated().sum())
# Out:
# 0
# 0

# %%
product['discount']=product['mrp']-product['price']
product['discount_percentage']=(product['discount']/product['mrp'])*100

# %%
product.head(10)
# Out:
#    product_id product_name             category                    brand  \
# 0      153019       Onions  Fruits & Vegetables               Aurora LLC
# 1       11422     Potatoes  Fruits & Vegetables           Ramaswamy-Tata
# 2      669378     Potatoes  Fruits & Vegetables          Chadha and Sons
# 3      848226     Tomatoes  Fruits & Vegetables           Barad and Sons
# 4      890623       Onions  Fruits & Vegetables  Sangha, Nagar and Varty
# 5      965755      Bananas  Fruits & Vegetables   Doshi, Sarraf and Sama
# 6      222892     Tomatoes  Fruits & Vegetables       Ramakrishnan-Ghose
# 7      516376       Onions  Fruits & Vegetables             Agarwal-Dhar
# 8       39154      Mangoes  Fruits & Vegetables   Suresh, Bose and Bajwa
# 9       34186      Mangoes  Fruits & Vegetables               Mandal-Kar
#
#     price      mrp  margin_percentage  shelf_life_days  min_stock_level  \
# 0  947.95  1263.93               25.0                3               13
# ...

# %%
product.shape
# Out:
# (268, 12)

# %%
from numpy._core.fromnumeric import prod
order.to_csv("cleaned_orders.csv", index=False)

df.to_csv("cleaned_customers.csv", index=False)

df1.to_csv("cleaned_customer_feedback.csv", index=False)
order_item.to_csv("cleaned_order_item.csv", index=False)
market_perf.to_csv("cleaned_market_performance.csv", index=False)
df2.to_csv("cleaned_delivery_perf.csv", index=False)

inv.to_csv("cleaned_inventory.csv", index=False)

inv_new.to_csv("cleaned_inventoryNew.csv", index=False)
product.to_csv("product_cleaned.csv", index=False)
